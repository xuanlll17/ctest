# %%
import plotly.express as px
import pandas as pd

# 讀取 CSV 檔案
df1 = pd.read_csv("../six_age_2023.csv")

# 將資料按照年和月進行分組，計算每個月的信用卡消費金額總和
monthly_total = df1.groupby(['年', '月'])['信用卡交易金額'].sum().reset_index()

# 繪製折線圖
fig = px.line(monthly_total, x="月", y="信用卡交易金額", color="年", title='age每月信用卡消費金額變化', markers=True)

# 顯示圖表
fig.show()

# 讀取 CSV 檔案
df2 = pd.read_csv("../six_job_2023.csv")

# 將資料按照年和月進行分組，計算每個月的信用卡消費金額總和
monthly = df2.groupby(['年', '月'])['信用卡交易金額'].sum().reset_index()

# 繪製折線圖
fig = px.line(monthly, x="月", y="信用卡交易金額", color="年", title='job每月信用卡消費金額變化', markers=True)

# 顯示圖表
fig.show()

# %%
import plotly.express as px
import pandas as pd

# Read CSV files
df_age = pd.read_csv("../six_age_2023.csv")
df_job = pd.read_csv("../six_job_2023.csv")
df_edu = pd.read_csv("../six_edu_2023.csv")
df_sex = pd.read_csv("../six_sex_2023.csv")
df_incom = pd.read_csv("../six_incom_2023.csv")

# Group by year and month and calculate monthly total for age data
monthly_age = df_age.groupby(['年', '月'])['信用卡交易金額'].sum().reset_index()
monthly_age['Category'] = 'Age'

# Group by year and month and calculate monthly total for job data
monthly_job = df_job.groupby(['年', '月'])['信用卡交易金額'].sum().reset_index()
monthly_job['Category'] = 'Job'
monthly_incom = df_job.groupby(['年', '月'])['信用卡交易金額'].sum().reset_index()
monthly_incom['Category'] = 'incom'
monthly_sex = df_job.groupby(['年', '月'])['信用卡交易金額'].sum().reset_index()
monthly_sex['Category'] = 'sex'
monthly_edu = df_job.groupby(['年', '月'])['信用卡交易金額'].sum().reset_index()
monthly_edu['Category'] = 'edu'

# Combine the dataframes
combined_df = pd.concat([monthly_age, monthly_job, monthly_incom, monthly_sex, monthly_edu], ignore_index=True)

# Plot combined data on one chart
fig = px.line(combined_df, x="月", y="信用卡交易金額", color="Category", line_group="年",
              title='每月信用卡消費金額變化', markers=True)

# Show the chart
fig.show()

# %%
import plotly.express as px
import pandas as pd

# 讀取 CSV 檔案
df = pd.read_csv("../six_age_2023.csv")

# 將資料按照年和月進行分組，計算每個月的信用卡消費金額總和
monthly_total = df.groupby(['年', '月', '年齡層'])['信用卡交易金額'].sum().reset_index()

# 繪製折線圖
fig = px.line(monthly_total, x="月", y="信用卡交易金額", color="年齡層", title='每月信用卡消費金額變化', markers=True)

# 顯示圖表
fig.show()

# %%
import plotly.express as px
import pandas as pd

# 讀取 CSV 檔案
df = pd.read_csv("../six_age_2023.csv")

# 選擇產業別為 '衣' 的資料
filtered_df = df[df['產業別'] == '衣']
display(filtered_df)

# 使用 px.pie 繪製圓餅圖
fig = px.pie(filtered_df, values='信用卡交易金額', names='年齡層',
             title='各年齡層在衣產業別的信用卡消費總金額')

# 顯示圖表
fig.show()

# %%
import plotly.express as px
import pandas as pd

# 讀取 CSV 檔案
df = pd.read_csv("../six_age_2023.csv")

# 使用 px.pie 繪製圓餅圖
fig = px.pie(df, values='信用卡交易金額', names='年齡層',
             title='各年齡層在不同產業別的信用卡消費總金額')

# 顯示圖表
fig.show()

# %%
import socket
myip = socket.gethostbyname(socket.gethostname())
print(myip)

# %%
import data
df = data.edu_data()
df

# %%
industry_values = {t[3] for t in df}
print(industry_values)

# %%
import pandas as pd
import plotly.express as px

# Assuming df is your list of tuples
df = pd.DataFrame(df, columns=["年", "月", "地區", "產業別", "教育程度", "信用卡交易筆數", "信用卡交易金額"])

# Group by industry and sum the transaction amounts
industry_sum = df.groupby('產業別')['信用卡交易金額'].sum().reset_index()

# Create a pie chart
fig = px.pie(industry_sum, values='信用卡交易金額', names='產業別', title='各產業別信用卡交易金額總和')
fig.show()

# %%
import pandas as pd
import plotly.express as px

# Read the CSV file
wide_df = pd.read_csv("../six_age_2023.csv")

# Group by region and sum the credit card transaction amounts
region_sum = wide_df.groupby('地區')['信用卡交易金額'].sum().reset_index()

# Create a bar chart
fig = px.bar(region_sum, x='地區', y='信用卡交易金額', title='Total Credit Card Transaction Amount by Region')
fig.show()

# %%
import pandas as pd
import plotly.express as px

# Read the CSV file
wide_df = pd.read_csv("../six_age_2023.csv")

# Group by region and sum the credit card transaction amounts
region_sum = wide_df.groupby('地區')['信用卡交易金額'].sum().reset_index()

# Create a bar chart
fig = px.bar(region_sum, x='地區', y='信用卡交易金額', title='Total Credit Card Transaction Amount by Region')

# Highlight a specific region (e.g., '臺北市') in a different color
highlighted_region = '臺北市'
fig.update_traces(marker_color=['blue' if region == highlighted_region else 'gray' for region in region_sum['地區']])

fig.show()

# %%
import dash
import dash_bootstrap_components as dbc

app = dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])

app.layout = dbc.ListGroup(
    [
        dbc.ListGroupItem("Item 1"),
        dbc.ListGroupItem("Item 2", style={"width": "200px"}),
        dbc.ListGroupItem("Item 3"),
    ],
    className="list-group-horizontal",
)

if __name__ == "__main__":
    app.run_server(debug=True)

# %%
import matplotlib.pyplot as plt


# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = [
    'Chemicals', 'Oil & gas', 'Textiles& Mining', 'Food & Breverages', 'Others'
]
colors = ['#01579B', '#2E86C1', '#3498DB', '#2874A6', '#1B4F72']
sizes = [31, 24, 7, 5, 33]
explode = (0, 0, 0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(
    sizes, explode=explode, labels=labels, autopct='%1.1f%%', startangle=90,
    colors=colors, textprops={'fontsize': 13}
)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

selection = 'Chemicals'
for patch, text, autotext in zip(patches, texts, autotexts):
    autotext.set_color('white')
    autotext.set_weight('bold')
    if text.get_text() != selection:
        patch.set_alpha(0.2)

# plt.savefig('filename1.png', dpi=300)
plt.show()

# %%
import plotly.express as px

# Data
labels = ['Chemicals', 'Oil & gas', 'Textiles& Mining', 'Food & Breverages', 'Others']
colors = ['#01579B', '#2E86C1', '#3498DB', '#2874A6', '#1B4F72']
sizes = [31, 24, 7, 5, 33]

# Create Pie Chart
fig = px.pie(
    names=labels,
    values=sizes,
    color_discrete_sequence=colors,
    labels={'names': 'Categories', 'values': 'Percentage'},
    title='Distribution of Industries',
)

# Highlight selected category
fig.update_traces(
    textinfo='percent+label',
    pull=[0.2 if label != 'Chemicals' else 0 for label in labels],  # Highlight 'Chemicals'
)


# Show the plot
fig.show()

# %%
import plotly.express as px

# Data
labels = ['Chemicals', 'Oil & gas', 'Textiles& Mining', 'Food & Breverages', 'Others']
sizes = [31, 24, 7, 5, 33]

# Create Pie Chart
fig = px.pie(
    names=labels,
    values=sizes,
    labels={'names': 'Categories', 'values': 'Percentage'},
    title='Distribution of Industries',
)

# Highlight selected category
#fig.update_traces(
    #marker=dict(colors=['rgba(1,87,155,1)' if label == 'Chemicals' else 'rgba(1,87,155,0.2)' for label in labels]),
#)



# Show the plot
fig.show()

# %%
import plotly.express as px

# Data
labels = ['Chemicals', 'Oil & gas', 'Textiles& Mining', 'Food & Breverages', 'Others']
sizes = [31, 24, 7, 5, 33]

# Create Pie Chart
fig = px.pie(
    names=labels,
    values=sizes,
    labels={'names': 'Categories', 'values': 'Percentage'},
    title='Distribution of Industries',
)

# Set opacity to 0.2 for categories other than 'Chemicals'
for i, label in enumerate(labels):
    if label != 'Chemicals':
        fig.data[0].marker.line.color[i] = 'rgba(255, 255, 255, 0.2)'

# Show the plot
fig.show()

# %%
import plotly.express as px

# Data
labels = ['Chemicals', 'Oil & gas', 'Textiles& Mining', 'Food & Breverages', 'Others']
colors = ['#01579B', '#2E86C1', '#3498DB', '#2874A6', '#1B4F72']
sizes = [31, 24, 7, 5, 33]

# Create Pie Chart
fig = px.pie(
    names=labels,
    values=sizes,
    color_discrete_sequence=colors,
    hole=0.3,  # Set to 0 for a full pie chart
    labels={'names': 'Categories', 'values': 'Percentage'},
    title='Distribution of Industries',
)

# Highlight selected category
fig.update_traces(
    opacity=0.2,  # Set the opacity for all categories
    textinfo='percent+label',
)

# Customize layout
fig.update_layout(
    showlegend=False,  # Remove legend
)

# Show the plot
fig.show()

# %%
import plotly.express as px

# Data
labels = ['Chemicals', 'Oil & gas', 'Textiles& Mining', 'Food & Breverages', 'Others']
sizes = [31, 24, 7, 5, 33]

# Create Pie Chart
fig = px.pie(
    names=labels,
    values=sizes,
    labels={'names': 'Categories', 'values': 'Percentage'},
    title='Distribution of Industries',
)

# Highlight selected category
fig.update_traces(
    marker=dict(colors=[]),
    textinfo='percent+label',
)



# Show the plot
fig.show()

# %%
import plotly.express as px

# Data
labels = ['Chemicals', 'Oil & gas', 'Textiles& Mining', 'Food & Breverages', 'Others']
sizes = [31, 24, 7, 5, 33]

# Create Pie Chart
fig = px.pie(
    names=labels,
    values=sizes,
    labels={'names': 'Categories', 'values': 'Percentage'},
    title='Distribution of Industries',
)

# Highlight selected category ('Others')
highlight_category = 'Others'


fig.update_traces(
    marker=dict(colors=['rgba(1,87,155,0.2)' if label != highlight_category else '' for label in labels]),
    textinfo='percent+label',
)

# Show the plot
fig.show()

# %%
import plotly.express as px

# Data
labels = ['Chemicals', 'Oil & gas', 'Textiles& Mining', 'Food & Breverages', 'Others']
sizes = [31, 24, 7, 5, 33]

# Create Pie Chart
fig = px.pie(
    names=labels,
    values=sizes,
    labels={'names': 'Categories', 'values': 'Percentage'},
    title='Distribution of Industries',
)

highlight_category = 'Others'

fig.update_traces(
    opacity=0.2 if highlight_category != 'Others' else 1,
    textinfo='percent+label',
)

# Show the plot
fig.show()

# %%
import plotly.express as px

# Data
labels = ['Chemicals', 'Oil & gas', 'Textiles& Mining', 'Food & Breverages', 'Others']
sizes = [31, 24, 7, 5, 33]

# Create Pie Chart
fig = px.pie(
    names=labels,
    values=sizes,
    labels={'names': 'Categories', 'values': 'Percentage'},
    title='Distribution of Industries',
)

highlight_category = 'Others'
opacity_values = [0.2 if label != highlight_category else 1 for label in labels]

# Manually set opacity in color_discrete_sequence
fig.update_traces(
    marker=dict(colors=['rgba(31,119,180,' + str(opacity) + ')' for opacity in opacity_values]),
    textinfo='percent+label',
)

# Show the plot
fig.show()

# %%
import plotly.express as px
import pandas as pd
df = pd.read_csv("../six_edu_2023.csv")
industry_sum = df.groupby('產業別')['信用卡交易金額'].sum().reset_index()
fig = px.bar(industry_sum, x='信用卡交易金額', y='產業別', orientation='h')
fig.show()


# Create a pie chart
fig = px.pie(industry_sum, values='信用卡交易金額', names='產業別', title='各產業別信用卡交易金額總和')
fig.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

lastest_df = pd.read_csv("../six_edu_2023.csv")


levels = ['產業別', '地區', '教育程度類別']  # Modify the levels according to your DataFrame
color_columns = ['信用卡交易金額', '信用卡交易筆數']
value_column = '信用卡交易筆數'

def build_hierarchical_dataframe(df, levels, value_column, color_columns=None):
    df_all_trees = pd.DataFrame(columns=['id', 'parent', 'value', 'color'])
    for i, level in enumerate(levels):
        df_tree = pd.DataFrame(columns=['id', 'parent', 'value', 'color'])
        dfg = df.groupby(levels[i:]).sum()
        dfg = dfg.reset_index()
        df_tree['id'] = dfg[level].copy()
        if i < len(levels) - 1:
            df_tree['parent'] = dfg[levels[i+1]].copy()
        else:
            df_tree['parent'] = 'total'
        df_tree['value'] = dfg[value_column]
        df_tree['color'] = dfg[color_columns[0]] / dfg[color_columns[1]]
        
        if not df_all_trees.empty:
            df_all_trees = pd.concat([df_all_trees, df_tree], ignore_index=True)
        else:
            df_all_trees = df_tree
    
    total = pd.Series(dict(id='total', parent='',
                              value=df[value_column].sum(),
                              color=df[color_columns[0]].sum() / df[color_columns[1]].sum()))
    
    if not df_all_trees.empty:
        df_all_trees = pd.concat([df_all_trees, pd.DataFrame([total])], ignore_index=True)
    else:
        df_all_trees = pd.DataFrame([total])
    
    return df_all_trees


df_all_trees = build_hierarchical_dataframe(lastest_df, levels, value_column, color_columns)
average_score = lastest_df['信用卡交易金額'].sum() / lastest_df['信用卡交易筆數'].sum()

fig = make_subplots(1, 2, specs=[[{"type": "domain"}, {"type": "domain"}]],)

fig.add_trace(go.Sunburst(
    labels=df_all_trees['id'],
    parents=df_all_trees['parent'],
    values=df_all_trees['value'],
    branchvalues='total',
    marker=dict(
        colors=df_all_trees['color'],
        colorscale='RdBu',
        cmid=average_score),
    hovertemplate='<b>%{label} </b> <br> 信用卡交易筆數: %{value}<br> 信用卡交易金額: %{color:.2f}',
    name=''
    ), 1, 1)

fig.add_trace(go.Sunburst(
    labels=df_all_trees['id'],
    parents=df_all_trees['parent'],
    values=df_all_trees['value'],
    branchvalues='total',
    marker=dict(
        colors=df_all_trees['color'],
        colorscale='RdBu',
        cmid=average_score),
    hovertemplate='<b>%{label} </b> <br> 信用卡交易筆數: %{value}<br> 信用卡交易金額: %{color:.2f}',
    maxdepth=2
    ), 1, 2)

fig.update_layout(margin=dict(t=10, b=10, r=10, l=10))
fig.show()

# %%
import pandas as pd
import plotly.express as px

# Read the CSV file
latest_df = pd.read_csv('../six_edu_2023.csv')

# Assuming your dataset has the following columns
columns = ["年", "月", "地區", "產業別", "教育程度類別", "信用卡交易筆數", "信用卡交易金額"]

# Create a hierarchical DataFrame for the Sunburst chart
df_all_trees = pd.DataFrame(columns=['id', 'parent', 'value'])

for i, level in enumerate(columns[:-1]):
    dfg = latest_df.groupby(columns[:i + 2]).sum().reset_index()
    df_tree = pd.DataFrame({
        'id': dfg[level].copy(),
        'parent': dfg[columns[i + 1]].copy(),
        'value': dfg[columns[-1]]
    })
    df_all_trees = pd.concat([df_all_trees, df_tree], ignore_index=True)

total = pd.Series(dict(id='total', parent='', value=latest_df[columns[-1]].sum()))
df_all_trees = pd.concat([df_all_trees, pd.DataFrame([total])], ignore_index=True)

# Create the Sunburst chart
fig = px.sunburst(
    df_all_trees,
    names='id',
    parents='parent',
    values='value',
)

# Show the plot
fig.show()

# %%
import plotly.express as px
import pandas as pd
df = pd.read_csv('../six_edu_2023.csv')

fig = px.sunburst(df, path=['年','月', '產業別', '教育程度類別'], values='信用卡交易金額')
filtered_df = df[df['月'] == 3]
fig = px.sunburst(filtered_df, path=['月', '產業別', '教育程度類別'], values='信用卡交易金額')
fig.show()

# %%
from dash import Dash, html
import base64
from PIL import Image

image_path = 'assets/images/my-image.png'

pil_img = Image.open(image_path)

def b64_image(image_filename):
    with open(image_filename, 'rb') as f:
        image = f.read()
    return 'data:image/png;base64,' + base64.b64encode(image).decode('utf-8')


app = Dash(__name__)

app.layout = html.Div([
    html.H1('Dash'),
    html.Img(src=image_path),
])

if __name__ == "__main__":
    app.run_server(host="localhost", port=8050)

# %%
from dash import Dash, html
import base64
import os

image_folder = 'assets/images/'

def b64_image(image_filename):  #image_filename->變數名稱
    with open(image_filename, 'rb') as f:  #rb->二進位讀檔
        image = f.read()  #讀取檔案內容,傳回一包含檔案內容字串或二進位數據(?)
    return 'data:image/png;base64,' + base64.b64encode(image).decode('utf-8')

image_paths = [os.path.join(image_folder, filename) for filename in os.listdir(image_folder)]

app = Dash(__name__)

app.layout = html.Div([
    html.H1('Dash'),
    
    *[html.Img(src=b64_image(image_path)) for image_path in image_paths],
])

if __name__ == "__main__":
    app.run_server(host="localhost", port=8050)

# %%
from dash import Dash, html, dcc, callback, Input, Output, State
import base64
import os

image_folder = 'assets/images/'

def b64_image(image_filename):
    with open(image_filename, 'rb') as f:
        image = f.read()
    return 'data:image/png;base64,' + base64.b64encode(image).decode('utf-8')

image_paths = [os.path.join(image_folder, filename) for filename in os.listdir(image_folder)]

app = Dash(__name__)

app.layout = html.Div([
    html.H1('Dash'),
    
    html.Button('Show Images', id='show-button'),
    
    html.Div(id='image-container'),
    
    dcc.Store(id='button-state', data=False)
])

@app.callback(
    Output('image-container', 'children'),
    Input('show-button', 'n_clicks'),
    State('button-state', 'data')
)
def update_images(n_clicks, button_state):
    if n_clicks is None:
        return []
    
    # Toggle button state
    button_state = not button_state
    
    # Return images only if the button is clicked
    if button_state:
        return [html.Img(src=b64_image(image_path)) for image_path in image_paths]
    else:
        return []

@app.callback(
    Output('button-state', 'data'),
    Input('show-button', 'n_clicks')
)
def update_button_state(n_clicks):
    if n_clicks is None:
        return False
    
    # Toggle button state
    return not n_clicks % 2 == 0

if __name__ == "__main__":
    app.run_server(host="localhost", port=8050)

# %%
from dash import Dash, html, dcc, callback, Input, Output, State
import base64
import os

image_folder = 'assets/images/'

def b64_image(image_filename):
    with open(image_filename, 'rb') as f:
        image = f.read()
    return 'data:image/png;base64,' + base64.b64encode(image).decode('utf-8')

image_paths = [os.path.join(image_folder, filename) for filename in os.listdir(image_folder)]

app = Dash(__name__)

app.layout = html.Div([
    html.H1('Dash'),
    
    html.Button('Show Image', id='show-button'),
    
    html.Img(id='displayed-image'),
    
    dcc.Store(id='image-index', data=0)
])

@app.callback(
    Output('displayed-image', 'src'),
    Input('show-button', 'n_clicks'),
    State('image-index', 'data')
)
def update_image_src(n_clicks, image_index):
    if n_clicks is None:
        return b64_image(image_paths[0])
    
    # Increment image index and reset if it exceeds the number of images
    image_index = (image_index + 1) % len(image_paths)
    
    return b64_image(image_paths[image_index])

@app.callback(
    Output('image-index', 'data'),
    Input('show-button', 'n_clicks')
)
def update_image_index(n_clicks):
    if n_clicks is None:
        return 0
    
    return n_clicks % len(image_paths)

if __name__ == "__main__":
    app.run_server(host="localhost", port=8050)

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.express as px
import pandas as pd

lastest_df = pd.read_csv('../six_edu_2023.csv')

app = dash.Dash(__name__)

app.layout = html.Div([
    dcc.Dropdown(
        id='month',
        options=[
            {'label': '一月', 'value': '1'},
            # Add other months as needed
        ],
        value='ALL',
        style={'width': '50%'}
    ),
    dcc.Graph(id='graph_sunburst'),
])

@app.callback(
    Output("graph_sunburst", "figure"),
    Input("month", "value")
)
def update_sunburst_chart(selected_mon):
    global lastest_df
    if selected_mon == "ALL":
        fig = px.sunburst(lastest_df, path=['年', '月', '產業別', '教育程度類別'], values='信用卡交易金額',width=500, height=600)
    else:
        filtered_df = lastest_df[lastest_df['月'].astype(str) == selected_mon]
        fig = px.sunburst(filtered_df, path=['月', '產業別', '教育程度類別'], values='信用卡交易金額',width=1800, height=800)
    return fig

if __name__ == '__main__':
    app.run_server(host="localhost", port=8050,debug=True)

# %%
import plotly.express as px
tips = px.data.tips()
fig = px.bar(tips, x='sex', y='total_bill', color='smoker', barmode='group')

fig.update_layout({
'plot_bgcolor': 'rgba(0, 0, 0, 0)',
'paper_bgcolor': 'rgba(0, 0, 0, 0)',
})

fig.show()

# %%
import plotly.express as px
import pandas as pd

df = pd.DataFrame(dict(
    Date=[1, 2, 3],
    Averaged=[1, 2, 3],
    Raw=[2, 3, 1]
))

fig = px.line(df, x="Date", y="Raw")

# Update line color to goldenrod
for trace in fig.data:
    trace.line.color = 'goldenrod'
    trace.line.width = 5  # Set the desired line width

fig.show()

# %%
import pandas as pd
import plotly.express as px

# Assuming df is your DataFrame
df['平均交易金額'] = df['信用卡交易金額[新台幣]'] / df['信用卡交易筆數']

# Group by industry and calculate the sum of values
agg_df = df.groupby('產業別').agg({'信用卡交易金額[新台幣]': 'sum'}).reset_index()

# Calculate the average transaction amount for each industry
agg_df['平均交易金額'] = agg_df['信用卡交易金額[新台幣]'] / agg_df['信用卡交易筆數']

# Create a combined bar and line chart using Plotly Express
fig = px.bar(agg_df, x='產業別', y='信用卡交易金額[新台幣]', title='不同產業別的信用卡交易金額',
             labels={'產業別': '產業別', '信用卡交易金額[新台幣]': '信用卡交易金額'},
             width=800, height=400)

fig.add_trace(px.line(agg_df, x='產業別', y='平均交易金額', line_shape='linear',
                     labels={'產業別': '產業別', '平均交易金額': '平均交易金額'})
                     .update_traces(line=dict(color='red', dash='solid', width=2)).data[0])

# Update layout to have a secondary y-axis for '平均交易金額'
fig.update_layout(yaxis2=dict(title='平均交易金額', overlaying='y', side='right'))

# Show the plot
fig.show()

# %%
import pandas as pd
import plotly.express as px

# Assuming df is your DataFrame
df['平均交易金額'] = df['信用卡交易金額[新台幣]'] / df['信用卡交易筆數']

# Group by industry and calculate the sum of values
agg_df = df.groupby('產業別').agg({'信用卡交易金額[新台幣]': 'sum', '信用卡交易筆數': 'sum'}).reset_index()

# Calculate the average transaction amount for each industry
agg_df['平均交易金額'] = agg_df['信用卡交易金額[新台幣]'] / agg_df['信用卡交易筆數']

# Print aggregated DataFrame for inspection
print(agg_df)

# Create a combined bar and line chart using Plotly Express
fig = px.bar(agg_df, x='產業別', y='信用卡交易金額[新台幣]', title='不同產業別的信用卡交易金額',
             labels={'產業別': '產業別', '信用卡交易金額[新台幣]': '信用卡交易金額'},
             width=800, height=400)

fig.add_trace(px.line(agg_df, x='產業別', y='平均交易金額', line_shape='linear',
                     labels={'產業別': '產業別', '平均交易金額': '平均交易金額'})
                     .update_traces(line=dict(color='red', dash='solid', width=2)).data[0])

# Update layout to have a secondary y-axis for '平均交易金額'
fig.update_layout(yaxis2=dict(title='平均交易金額', overlaying='y', side='right'))

# Show the plot
fig.show()

# %%
import pandas as pd
import plotly.graph_objects as go

# Assuming df is your DataFrame
df['平均交易金額'] = df['信用卡交易金額[新台幣]'] / df['信用卡交易筆數']

# Group by industry and calculate the sum of values
agg_df = df.groupby('產業別').agg({'信用卡交易金額[新台幣]': 'sum', '信用卡交易筆數': 'sum'}).reset_index()

# Calculate the average transaction amount for each industry
agg_df['平均交易金額'] = agg_df['信用卡交易金額[新台幣]'] / agg_df['信用卡交易筆數']

# Print aggregated DataFrame for inspection
print(agg_df)

# Create a combined bar and line chart using go.Bar and go.Scatter
fig = go.Figure()

# Add bar trace
fig.add_trace(go.Bar(x=agg_df['產業別'], y=agg_df['信用卡交易金額[新台幣]'], name='信用卡交易金額[新台幣]'))

# Add line trace
fig.add_trace(go.Scatter(x=agg_df['產業別'], y=agg_df['平均交易金額'], mode='lines', name='平均交易金額',
                         line=dict(color='red', dash='solid', width=2)))

# Update layout to have a secondary y-axis for '平均交易金額'
fig.update_layout(yaxis2=dict(title='平均交易金額', overlaying='y', side='right'))

# Show the plot
fig.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Scatter(x=[1, 2, 3], y=[40, 50, 60], name="yaxis data"),
    secondary_y=False,
)

fig.add_trace(
    go.Scatter(x=[2, 3, 4], y=[4, 5, 6], name="yaxis2 data"),
    secondary_y=True,
)

# Add figure title
fig.update_layout(
    title_text="Double Y Axis Example"
)

# Set x-axis title
fig.update_xaxes(title_text="xaxis title")

# Set y-axes titles
fig.update_yaxes(title_text="<b>primary</b> yaxis title", secondary_y=False)
fig.update_yaxes(title_text="<b>secondary</b> yaxis title", secondary_y=True)

fig.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

# Assuming df is your DataFrame with the desired data
dataset = pd.read_csv("../age.csv")
df = pd.DataFrame(dataset)
df['平均交易金額'] = df['信用卡交易金額[新台幣]'] / df['信用卡交易筆數']

# Aggregate data by summing values for each industry
agg_df = df.groupby('產業別').agg({
    '信用卡交易金額[新台幣]': 'sum',
    '信用卡交易筆數': 'sum',
    '平均交易金額': 'mean'  # You can adjust this based on your specific requirement for average
}).reset_index()

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add bar trace
fig.add_trace(
    go.Bar(x=agg_df['產業別'], y=agg_df['信用卡交易金額[新台幣]'], name="信用卡交易金額[新台幣]"),
    secondary_y=False,
)

# Add line trace
fig.add_trace(
    go.Scatter(x=agg_df['產業別'], y=agg_df['平均交易金額'], name="平均交易金額", mode='lines+markers', marker=dict(color='red')),
    secondary_y=True,
)

# Add figure title
fig.update_layout(
    title_text="不同產業別的信用卡交易金額及平均交易金額"
)

# Set x-axis title
fig.update_xaxes(title_text="產業別")

# Set y-axes titles
fig.update_yaxes(title_text="信用卡交易金額[新台幣]", secondary_y=False)
fig.update_yaxes(title_text="平均交易金額", secondary_y=True)

# Show the plot
fig.show()

# %%
from dash import Dash, html, Input, Output, dcc
import dash_bootstrap_components as dbc
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

dash_ML = Dash(
    requests_pathname_prefix="/dash/ML/", external_stylesheets=[dbc.themes.BOOTSTRAP]
)
dash_ML.title = "信用卡消費樣態"
lastest_data = pd.read_csv("../processed_dataset.csv")
df = pd.DataFrame(lastest_data)

dash_ML.layout = html.Div(
    [
        dbc.Container(
            [
                html.Div(
                    [html.Div([html.H1("信用卡消費樣態")], className="col text-center")],
                    className="row",
                    style={"padding": "3rem 0 1rem 0"},
                ),
                html.Div(
                    [
                        dbc.InputGroup(
                            [
                                dbc.InputGroupText("月份"),
                                dbc.Select(
                                    id="month",
                                    value="ALL",
                                    options=[
                                        {"label": "1月", "value": "1"},
                                        {"label": "2月", "value": "2"},
                                        {"label": "3月", "value": "3"},
                                        {"label": "4月", "value": "4"},
                                        {"label": "5月", "value": "5"},
                                        {"label": "6月", "value": "6"},
                                        {"label": "7月", "value": "7"},
                                        {"label": "8月", "value": "8"},
                                        {"label": "9月", "value": "9"},
                                        {"label": "ALL", "value": "ALL"},
                                    ],
                                    style={"marginRight": "1rem"},
                                ),
                            ],
                        ),
                        dbc.InputGroup(
                            [
                                dbc.InputGroupText("地區"),
                                dbc.Select(
                                    id="area",
                                    value="ALL",
                                    options=[
                                        {"label": "臺北市", "value": "臺北市"},
                                        {"label": "新北市", "value": "新北市"},
                                        {"label": "桃園市", "value": "桃園市"},
                                        {"label": "臺中市", "value": "臺中市"},
                                        {"label": "臺南市", "value": "臺南市"},
                                        {"label": "高雄市", "value": "高雄市"},
                                        {"label": "ALL", "value": "ALL"},
                                    ],
                                    style={"marginRight": "1rem"},
                                ),
                            ],
                        ),
                        dbc.InputGroup(
                            [
                                dbc.InputGroupText("產業別"),
                                dbc.Select(
                                    id="industry",
                                    value="ALL",
                                    options=[
                                        {"label": "食", "value": "食"},
                                        {"label": "衣", "value": "衣"},
                                        {"label": "住", "value": "住"},
                                        {"label": "行", "value": "行"},
                                        {"label": "文教康樂", "value": "文教康樂"},
                                        {"label": "百貨", "value": "百貨"},
                                        {"label": "ALL", "value": "ALL"},
                                    ],
                                    style={"marginRight": "1rem"},
                                ),
                            ],
                        ),
                        dbc.InputGroup(
                            [
                                dbc.InputGroupText("年齡層"),
                                dbc.Select(
                                    id="age",
                                    value="ALL",
                                    options=[
                                        {"label": "未滿20歲", "value": "未滿20歲"},
                                        {"label": "20(含)-25歲", "value": "20(含)-25歲"},
                                        {"label": "25(含)-30歲", "value": "25(含)-30歲"},
                                        {"label": "30(含)-35歲", "value": "30(含)-35歲"},
                                        {"label": "35(含)-40歲", "value": "35(含)-40歲"},
                                        {"label": "40(含)-45歲", "value": "40(含)-45歲"},
                                        {"label": "45(含)-50歲", "value": "45(含)-50歲"},
                                        {"label": "50(含)-55歲", "value": "50(含)-55歲"},
                                        {"label": "55(含)-60歲", "value": "55(含)-60歲"},
                                        {"label": "60(含)-65歲", "value": "60(含)-65歲"},
                                        {"label": "70(含)-75歲", "value": "70(含)-75歲"},
                                        {"label": "75(含)-80歲", "value": "75(含)-80歲"},
                                        {"label": "80(含)歲以上", "value": "80(含)歲以上"},
                                        {"label": "ALL", "value": "ALL"},
                                    ],
                                ),
                            ],
                        )
                    ],
                    className="d-flex justify-content-center",
                    style={"paddingTop": "2rem"},
                ),
                html.Div([
                    dcc.Graph(id="graph_line"),
                ]),
            ]
        )
    ],
    className="container-lg",
)

@dash_ML.callback(
    Output("graph_line", "figure"),
    Input("month", "value"),
    Input("area", "value"),
    Input("industry", "value"),
    Input("age", "value"),
)
def line_chart(selected_month, selected_area, selected_industry, selected_age):
    global df
    df['平均交易金額'] = df['信用卡交易金額[新台幣]'] / df['信用卡交易筆數']

    # Apply filters based on user selections
    filtered_df = df
    if selected_month != "ALL":
        filtered_df = filtered_df[filtered_df["月"] == int(selected_month)]
    if selected_area != "ALL":
        filtered_df = filtered_df[filtered_df["地區"] == selected_area]
    if selected_industry != "ALL":
        filtered_df = filtered_df[filtered_df["產業別"] == selected_industry]
    if selected_age != "ALL":
        filtered_df = filtered_df[filtered_df["年齡層"] == selected_age]

    # Aggregate data by summing values for each industry
    agg_df = filtered_df.groupby('產業別').agg({
        '信用卡交易金額[新台幣]': 'sum',
        '信用卡交易筆數': 'sum',
        '平均交易金額': 'mean'  # You can adjust this based on your specific requirement for average
    }).reset_index()

    # Create figure with secondary y-axis
    fig = make_subplots(specs=[[{"secondary_y": True}]])

    # Add bar trace
    fig.add_trace(
        go.Bar(x=agg_df['產業別'], y=agg_df['信用卡交易金額[新台幣]'], name="信用卡交易金額[新台幣]"),
        secondary_y=False,
    )

    # Add line trace
    fig.add_trace(
        go.Scatter(x=agg_df['產業別'], y=agg_df['平均交易金額'], name="平均交易金額", mode='lines+markers', marker=dict(color='red')),
        secondary_y=True,
    )

    # Add figure title
    fig.update_layout(
        title_text="不同產業別的信用卡交易金額及平均交易金額"
    )

    # Set x-axis title
    fig.update_xaxes(title_text="產業別")

    # Set y-axes titles
    fig.update_yaxes(title_text="信用卡交易金額[新台幣]", secondary_y=False)
    fig.update_yaxes(title_text="平均交易金額", secondary_y=True)
    return fig

if __name__ == "__main__":
    dash_ML.run_server(debug=True)
